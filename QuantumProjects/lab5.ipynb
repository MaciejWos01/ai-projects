# %% [markdown]
# # Introduction to Quantum Information and Quantum Machine Learning lab 5 report
# ## Maciej Woś, 148276

# %%
import numpy as np
from numpy import pi
from qiskit import *
from qiskit import QuantumCircuit, transpile
from qiskit_aer import Aer
from qiskit.visualization import plot_histogram, plot_bloch_multivector, plot_distribution

# %%
qc = QuantumCircuit(3)
qc.x(0)
qc.x(2)
qc.draw()
# Out:
#      ┌───┐
# q_0: ┤ X ├
#      └───┘
# q_1: ─────
#      ┌───┐
# q_2: ┤ X ├
#      └───┘

# %%
sim = Aer.get_backend("aer_simulator")
qc_init = qc.copy()
qc_init.save_statevector()
statevector = sim.run(qc_init).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
qc = QuantumCircuit(3)
qc.x(0)
qc.x(2)
qc.h(2)
qc.cp(pi/2, 1, 2) # CROT from qubit 1 to qubit 2
qc.cp(pi/4, 0, 2) # CROT from qubit 2 to qubit 0
qc.h(1)
qc.cp(pi/2, 0, 1) # CROT from qubit 0 to qubit 1
qc.h(0)
qc.swap(0,2)
qc.draw('mpl')
# Out:
# C:\Users\Maciej\anaconda3\envs\quantum\Lib\site-packages\qiskit\visualization\circuit\matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
qc.save_statevector()
statevector = sim.run(qc).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
qc.swap(0,2)
qc.h(0)
qc.cp(-pi/2, 0, 1) # CROT from qubit 0 to qubit 1
qc.h(1)
qc.cp(-pi/2, 1, 2) # CROT from qubit 1 to qubit 2
qc.cp(-pi/4, 0, 2) # CROT from qubit 2 to qubit 0
qc.h(2)
qc.measure_all()
qc.draw('mpl')

# %%
backend = Aer.get_backend('qasm_simulator')
shots = 2048
transpiled_qc = transpile(qc, backend,
optimization_level=3)
job = backend.run(transpiled_qc, shots=shots)
counts = job.result().get_counts()
plot_histogram(counts)

# %% [markdown]
# Task 1

# %%
def qft(qc):
    qc.h(2)
    qc.cp(pi/2, 1, 2)
    qc.cp(pi/4, 0, 2)
    qc.h(1)
    qc.cp(pi/2, 0, 1)
    qc.h(0)
    qc.swap(0,2)
    return qc

def iqft(qc):
    qc.swap(0,2)
    qc.h(0)
    qc.cp(-pi/2, 0, 1)
    qc.h(1)
    qc.cp(-pi/2, 1, 2)
    qc.cp(-pi/4, 0, 2)
    qc.h(2)
    qc.measure_all()
    return qc

# %%
n = 3
qc = QuantumCircuit(n)
qc.x(2)
iqft(qc)
qc.save_statevector()
statevector = sim.run(qc).result().get_statevector()
plot_bloch_multivector(statevector)

# %% [markdown]
# Task 2

# %%
n = 3
qc = QuantumCircuit(n)
qc.x(0)
qc.x(1)
iqft(qc)
qc.save_statevector()
statevector = sim.run(qc).result().get_statevector()
plot_bloch_multivector(statevector)

# %% [markdown]
# Task 3

# %%
n = 3
qc = QuantumCircuit(n)
qft(qc)
qc.save_statevector()
statevector = sim.run(qc).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
n = 3
qc = QuantumCircuit(n)
qc.x(0)
qft(qc)
qc.save_statevector()
statevector = sim.run(qc).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
n = 3
qc = QuantumCircuit(n)
qc.x(1)
qft(qc)
qc.save_statevector()
statevector = sim.run(qc).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
n = 3
qc = QuantumCircuit(n)
qc.x(0)
qc.x(1)
qft(qc)
qc.save_statevector()
statevector = sim.run(qc).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
n = 3
qc = QuantumCircuit(n)
qc.x(2)
qft(qc)
qc.save_statevector()
statevector = sim.run(qc).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
n = 3
qc = QuantumCircuit(n)
qc.x(0)
qc.x(2)
qft(qc)
qc.save_statevector()
statevector = sim.run(qc).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
n = 3
qc = QuantumCircuit(n)
qc.x(1)
qc.x(2)
qft(qc)
qc.save_statevector()
statevector = sim.run(qc).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
n = 3
qc = QuantumCircuit(n)
qc.x(0)
qc.x(1)
qc.x(2)
qft(qc)
qc.save_statevector()
statevector = sim.run(qc).result().get_statevector()
plot_bloch_multivector(statevector)
