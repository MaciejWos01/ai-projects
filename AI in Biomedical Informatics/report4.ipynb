# %% [markdown]
# # Project 04: Using simulation to assess trigger-generating mechanisms for digital health interventions
# ## Maciej Woś

# %% [markdown]
# Simulated Patient

# %%
import pandas as pd
import numpy as np
import os

from textwrap import wrap
from matplotlib import pyplot as plt
from stable_baselines3 import PPO, A2C, DQN
from sklearn.ensemble import RandomForestClassifier

# %%
from environment.fogg_behavioral_model import Patient

# %%
updated_every_day = 24 
week = 7 * updated_every_day

# %%
eight_weeks = week * 8
five_weeks = week * 5

# %%
# Basic stable condition
condition = 'stable'
habituation = False
time_preference_update_step = 9999999999999999 #very high e.g. 9999999999 to make it out of the intervention time...effectively no preference shift

# Other options (not considered in the AIBI project):
# condition = 'habituated'
# habituation=True
# time_preference_update_step= 9999999999999999 

# condition = 'changed_preference'
# habituation=False
# time_preference_update_step= five_weeks

# condition = 'habituated_changed_preference'
# habituation=True
# time_preference_update_step= five_weeks

# %%
# 500 runs in the paper
runs = 50

# %%
results_directory = 'results'
if not os.path.exists(results_directory):
    os.makedirs(results_directory)

# %% [markdown]
# Here is Part 1 of the tasks, where we prepared new class cluster0profile which represents cluster 0 (purple one) form the paper "Personality and habit formation: Is there a link?". In this cluster the only relevant positive responses were to statement: When I am tired I am unlikely to respond to reminders for healt-related activities. So we simulated scenario where patients who slept less than 6 hours would have decreased final behaviour.

# %%
class cluster0profile(Patient):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.characteristics = 1

    def fogg_behaviour(self, motivation: int, ability: int, trigger: bool) -> bool:
        self.calculate_characteristics()
        behavior = motivation * ability * trigger * self.characteristics
        return behavior > self.behavior_threshold

    def calculate_characteristics(self):
        recent_sleep = self.h_slept[-1]
        if recent_sleep < 6:
            self.characteristics = random.uniform(0.4, 0.8)
        else:
            self.characteristics = 1

# %% [markdown]
# In Part 2 we prepare another class which simulates patient who will be less responsive when stressed. In this case, when the value of patient's valence is equal 0, the behaviour will be decreased. In other scenario, when valence = 1, there is no change.

# %%
class stressed_profile(Patient):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.characteristics = 1

    def fogg_behaviour(self, motivation: int, ability: int, trigger: bool) -> bool:
        self.calculate_characteristics()
        behavior = motivation * ability * trigger * self.characteristics
        return behavior > self.behavior_threshold

    def calculate_characteristics(self):
        if self.valence == 0:
            self.characteristics = random.uniform(0.4, 0.8)
        else:
            self.characteristics = 1

# %% [markdown]
# # No interverntion

# %%
def no_intervention(profile):
    sleep_list = []
    positive_list = []
    
    for run in range(0, runs):
        
        env1 = profile(behavior_threshold=20, habituation=habituation, time_preference_update_step=time_preference_update_step)
        action = 0
        for i in  range(eight_weeks):
            
            observation, reward, done, _, info = env1.step(action)
            action = 0
        
        
        sleep_list.append(env1.h_slept)
        positive_list.append(env1.h_positive)
    
    fig = plt.figure( figsize=(8, 5))
    plt.plot(np.nanmean(sleep_list, axis=0), label='Hours slept', color ='r')
    plt.plot(np.mean(positive_list, axis=0), label='Hours in positive mood')
    plt.ylabel('Hours ')
    plt.xlabel('Intevention Days')
    plt.legend()
    plt.show()

# %%
no_intervention(cluster0profile)

# %% [markdown]
# # Intervention

# %%
def intervention(method, runs, name, condition, profile):
    rr_random_list = []
    not_random_list = []
    sleep_list = []
    positive_list = []
    performed = 0
    for run in range(0, runs):

        env1 = profile(behavior_threshold=20, habituation=habituation, time_preference_update_step=time_preference_update_step)
        env1 = method(env1)
        if sum(env1.num_performed):
            performed += 1
        df = pd.DataFrame()
        df['response_ratio'] = env1.rr
        df['activity performed'] = env1.num_performed
        df['notifications'] = env1.num_notified
        df['sleep'] = env1.h_slept
        df['positive'] = env1.h_positive
        df['non_stationary'] = env1.h_nonstationary
        
        df.to_csv("{0}/patient1_{1}_{2}_run{3}.csv".format(results_directory, condition, name, run))
        rr_random_list.append(df.response_ratio)
        not_random_list.append(df.notifications)
        sleep_list.append(df.sleep)
        positive_list.append(df.positive)

    """
    print("This figures include runs in which no prompt resulted in the activity being performed")
    print("{0} out of {1} resulted in activity being performed ".format(performed, runs))
    fig = plt.figure( figsize=(8, 5))
    plt.plot(np.nanmean(np.array(sleep_list), axis=0), label='Hours slept', color ='r')
    plt.plot(np.mean(positive_list, axis=0), label='Hours in positive mood')
    plt.ylabel('Hours ')
    plt.xlabel('Intevention Days')
    plt.legend()
    plt.show()

    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, sharey=False, figsize=(10, 8))
    ax1.plot(np.nanmean(rr_random_list, axis=0), label='response ratio', color ='r')
    ax2.plot(np.nanmean(not_random_list, axis=0), label='num of notifications')
    ax2.set_xlabel('Intervention days')
    ax2.set_ylabel('No. of notifications')
    ax1.set_ylabel('Response ratio')
    plt.show()
    """
    return sleep_list, positive_list, rr_random_list, not_random_list

# %% [markdown]
# ## Heuristic
#
# Notify every hour except in night and when the patient is alseep

# %%
def always_notify(env1, intervention_legth=eight_weeks):
    
    action = 0
    for i in  range(intervention_legth):
        
        observation, _, _, _, _ = env1.step(action)
        if observation[9] == 3 or observation[3] ==1:
            action = 0
        else:
            action = 1
            
    return env1

# %%
sleep_listh, positive_listh, rr_h_list, not_h_list = intervention(always_notify, runs, 'h', condition)
# Out:
# This figures include runs in which no prompt resulted in the activity being performed
# 33 out of 50 resulted in activity being performed

# %% [markdown]
# ## Random
# Randomly sample during the day skip the nights

# %%
def random_notification(env1, intervention_legth=eight_weeks):
    
    action = 0
    for i in  range(intervention_legth):
        
        observation, _, _, _, _ = env1.step(action)
        if observation[9] ==3:
            action = 0
        else:
            action = env1.action_space.sample()
            
    return env1

# %%
# %time _ = intervention(random_notification, runs, 'random', condition)
# Out:
# This figures include runs in which no prompt resulted in the activity being performed
# 41 out of 50 resulted in activity being performed
# CPU times: total: 2.34 s
# Wall time: 2.37 s

# %%
def get_rr_and_notification(name, runs, condition):
    
    rr, noti = [],[]
    failed = 0
    for run in range(runs):
        df = pd.read_csv("{0}/patient1_{1}_{2}_run{3}.csv".format(results_directory,condition, name, run))
        a_performed = sum(df['activity performed'].values)
        if a_performed > 0: # activity performed at least once in the course of the intervention
            rr.append(df.response_ratio)
            noti.append(df.notifications)
        else:
            failed = failed +1 
    print(" {0} out of {1} runs had no activity performed throughout the full intervention.".format(failed, runs))
    return rr, noti, failed

# %%
rr_random_list, not_random_list, fppo = get_rr_and_notification('random', runs, condition)
# Out:
#  9 out of 50 runs had no activity performed throughout the full intervention.

# %% [markdown]
# ## Supervised Learning
#
# ### Static model

# %%
def supervised_after_three_weeks(env1):
    
    three_weeks = 24 * 7 * 3
    env1 = always_notify(env1, intervention_legth=three_weeks)
    clf = RandomForestClassifier(class_weight='balanced')
    clf.fit(env1.observation_list, env1.activity_performed)
    remaining_time = eight_weeks - three_weeks
    observation = env1._get_current_state()
    for i in range(remaining_time):
        # applying supervised model
        action = clf.predict(np.array([observation]))[0]
        observation, _, _, _, _ = env1.step(action)
        
    return env1

# %%
# %time _ = intervention(supervised_after_three_weeks,runs , 'static_sup3', condition)
# Out:
# This figures include runs in which no prompt resulted in the activity being performed
# 27 out of 50 resulted in activity being performed
# CPU times: total: 3min 15s
# Wall time: 3min 24s

# %% [markdown]
# ### Adaptive model

# %%
def supervised_adaptive_after_three_weeks(env1):
    
    three_weeks = 24*7*3
    env1 = always_notify(env1, intervention_legth=three_weeks)
    clf = RandomForestClassifier(class_weight='balanced')
    clf.fit(env1.observation_list, env1.activity_performed)
    remaining_time = eight_weeks - three_weeks
    observation = env1._get_current_state()
    samples = len(env1.observation_list)
    for i in range(remaining_time):
        # applying supervised model
        action = clf.predict(np.array([observation]))[0]
        observation, _, _, _, _ = env1.step(action)
        if len(env1.observation_list)> samples: # retrain when new samples are provided
            clf = RandomForestClassifier(class_weight='balanced')
            clf.fit(env1.observation_list, env1.activity_performed)
            samples = len(env1.observation_list)
            
        
    return env1

# %%
# %time _ = intervention(supervised_adaptive_after_three_weeks, runs, 'adaptive_sup3', condition)
# Out:
# This figures include runs in which no prompt resulted in the activity being performed
# 27 out of 50 resulted in activity being performed
# CPU times: total: 3min 47s
# Wall time: 3min 50s

# %% [markdown]
# ### How many times supervised training faild?

# %%
rr_rf3_list, not_rf3_list, frf3 = get_rr_and_notification('static_sup3', runs, condition)
# Out:
#  23 out of 50 runs had no activity performed throughout the full intervention.

# %%
rr_rf3a_list, not_rf3a_list, frf3a = get_rr_and_notification('adaptive_sup3', runs, condition)
# Out:
#  23 out of 50 runs had no activity performed throughout the full intervention.

# %% [markdown]
# ## Deep Q Network

# %%
def dqn(env1):
    model = DQN("MlpPolicy", env1, verbose=0, learning_starts=updated_every_day)
    model.learn(total_timesteps=eight_weeks)
    return env1

# %%
# %time _= intervention(dqn, runs, 'dqn', condition)
# Out:
# This figures include runs in which no prompt resulted in the activity being performed
# 36 out of 50 resulted in activity being performed
# CPU times: total: 5min 54s
# Wall time: 1min 34s

# %%
rr_dqn_list, not_dqn_list, fdqn = get_rr_and_notification('dqn', runs, condition)
# Out:
#  14 out of 50 runs had no activity performed throughout the full intervention.

# %% [markdown]
# ## Proximal Policy Optimisation

# %%
def ppo(env1):
    model = PPO("MlpPolicy", env1, verbose=0, n_steps=updated_every_day, batch_size=updated_every_day)
    model.learn(total_timesteps=eight_weeks)
    return env1

# %%
# %time _= intervention(ppo, runs, 'ppo', condition)
# Out:
# This figures include runs in which no prompt resulted in the activity being performed
# 31 out of 50 resulted in activity being performed
# CPU times: total: 11min 22s
# Wall time: 2min 53s

# %%
rr_ppo_list, not_ppo_list, fppo = get_rr_and_notification('ppo', runs, condition)
# Out:
#  19 out of 50 runs had no activity performed throughout the full intervention.

# %% [markdown]
# ## Advantage Actor Critic

# %%
def a2c(env1):
    model = A2C("MlpPolicy", env1, verbose=0, n_steps=updated_every_day)
    model.learn(total_timesteps=eight_weeks)
    return env1

# %%
# %time _ = intervention(a2c, runs, 'a2c', condition)
# Out:
# This figures include runs in which no prompt resulted in the activity being performed
# 32 out of 50 resulted in activity being performed
# CPU times: total: 5min 14s
# Wall time: 1min 19s

# %%
rr_a2c_list, not_a2c_list, fppo = get_rr_and_notification('a2c', runs, condition)
# Out:
#  18 out of 50 runs had no activity performed throughout the full intervention.

# %% [markdown]
# ## Comparison between prompt learning stategies

# %%
def compare(profile):
    _ = intervention(random_notification, runs, 'random', condition, profile)
    rr_random_list, not_random_list, frandom = get_rr_and_notification('random', runs, condition)
    _ = intervention(supervised_after_three_weeks, runs, 'static_sup3', condition, profile)
    rr_rf3_list, not_rf3_list, frf3 = get_rr_and_notification('static_sup3', runs, condition)
    _ = intervention(supervised_adaptive_after_three_weeks, runs, 'adaptive_sup3', condition, profile)
    rr_rf3a_list, not_rf3a_list, frf3a = get_rr_and_notification('adaptive_sup3', runs, condition)
    _ = intervention(dqn, runs, 'dqn', condition, profile)
    rr_dqn_list, not_dqn_list, fdqn = get_rr_and_notification('dqn', runs, condition)
    _ = intervention(ppo, runs, 'ppo', condition, profile)
    rr_ppo_list, not_ppo_list, fppo = get_rr_and_notification('ppo', runs, condition)
    _ = intervention(random_notification, runs, 'a2c', condition, profile)
    rr_a2c_list, not_a2c_list, fa2c = get_rr_and_notification('a2c', runs, condition)
    fig, (ax1,ax2) = plt.subplots(2, 1, sharex=True, sharey=False, figsize=(10,10))
    ax1.plot(np.nanmean(rr_random_list, axis=0), label='Random')
    ax1.plot(np.nanmean(rr_rf3_list, axis=0), label='RF static')
    ax1.plot(np.nanmean(rr_rf3a_list, axis=0), label='RF adaptive')
    ax1.plot(np.nanmean(rr_dqn_list, axis=0), label='DQN')
    ax1.plot(np.nanmean(rr_ppo_list, axis=0), label='PPO')
    ax1.plot(np.nanmean(rr_a2c_list, axis=0), label='A2C')
    
    
    ax2.plot(np.nanmean(not_random_list, axis=0), label='Random')
    ax2.plot(np.nanmean(not_rf3_list, axis=0), label='RF static')
    ax2.plot(np.nanmean(not_rf3a_list, axis=0), label='RF adaptive')
    ax2.plot(np.nanmean(not_dqn_list, axis=0), label='DQN')
    ax2.plot(np.nanmean(not_ppo_list, axis=0), label='PPO')
    ax2.plot(np.nanmean(not_a2c_list, axis=0), label='A2C')
    ax2.plot(np.ones(len(np.mean(not_random_list, axis=0))) +2, label ='Preferred number of notifications a day')
    
    ax2.set_xlabel('Intervention Days', fontsize=16)
    ax2.set_ylabel('\n'.join(wrap('Numbers of notifications', 20)), fontsize=16)
    ax1.set_ylabel('\n'.join(wrap('Activity performed to prompt ratio', 20)) )
    # ax3.set_ylabel( '\n'.join(wrap('Hours slept', 20)) )
    # plt.ylim(0, 0.95)
    ax2.legend(fontsize=13)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.show()

# %%
compare(cluster0profile)
# Out:
#  9 out of 50 runs had no activity performed throughout the full intervention.
#  27 out of 50 runs had no activity performed throughout the full intervention.
#  29 out of 50 runs had no activity performed throughout the full intervention.
#  14 out of 50 runs had no activity performed throughout the full intervention.
#  11 out of 50 runs had no activity performed throughout the full intervention.
#  3 out of 50 runs had no activity performed throughout the full intervention.

# %%
compare(stressed_profile)
# Out:
#  12 out of 50 runs had no activity performed throughout the full intervention.
#  28 out of 50 runs had no activity performed throughout the full intervention.
#  28 out of 50 runs had no activity performed throughout the full intervention.
#  16 out of 50 runs had no activity performed throughout the full intervention.
#  16 out of 50 runs had no activity performed throughout the full intervention.
#  9 out of 50 runs had no activity performed throughout the full intervention.

# %% [markdown]
# # Conclusions
# In both profiles, the RF adaptive algorithm was the best (achieving 1.0 in some days) but was more stable in case of cluster0profile (the one with amount of sleep) than in case of stressed_profile (the one with valence). It is hard to say which algorithm was second best as RF static and PPO had similar performace, with DQN having slightly worse. Random and A2C algorithms were equally the worst, with high number of notifications during whole intervention process (around 8). In case of RF static and adaptive the number of notifications was high (around 15) but around 20th day it quickly decreased to less than 2 (the same moment when activity performed to prompt ratio increased). In case of PPO and DQN, number of notifications was high (around 12) but immediately started to decrease steadily and also achieving less than 2 notifications somewhere after 20th day. Another differences between those two profiles is that in case of RF static and PPO the ratio oscillated around 0.4 (RF static achieved even 0.8 once) for cluster0profile, and for stressed_profile it was around 0.3. Rest of the algorithms performed similarly in both profiles.
